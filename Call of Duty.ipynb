# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Warzone DPS.xlsx')
df.columns = ['Guns', 'Damage', 'Rate of Fire', 'DPS', 'STK', 'TTK', 'STK1', 'TTK1', 'STK2', 'TTK2', 'STK3', 'TTK3']
df['DPS'] = round(df['DPS'], 3)
df['TTK'] = round(df['TTK'], 3)
df['TTK1'] = round(df['TTK1'], 3)
df['TTK2'] = round(df['TTK2'], 3)
df['TTK3'] = round(df['TTK3'], 3)
df
# Out:
#                 Guns  Damage  Rate of Fire       DPS  STK      TTK  STK1  \
# 0           Kilo 141      28           779   363.533    4  231.065     6
# 1             FN FAL      54           500   450.000    2  120.000     3
# 2              AK-47      42           561   392.700    3  213.904     4
# 3     AK (5.45x39mm)      40           690   460.000    3  173.913     4
# 4               M4A1      28           833   388.733    4  216.086     6
# 5         M4A1 - 9mm      22          1034   379.133    4  174.081     7
# 6         M4A1 - 458      48           652   521.600    3  184.049     4
# 7             FR 556      40          1000   360.000    3  117.000     4
# 8               Oden      62           435   449.500    2  137.931     3
# 9                M13      24           923   369.200    5  260.022     7
# 10  M13 (300 BlkOut)      24           923   369.200    5  260.022     7
# 11           SCAR 17      35           600   350.000    3  200.000     5
# ...
